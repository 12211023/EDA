# %%
import pandas as pd


loan_1 = pd.read_csv('Loan 1.csv')
loan_2 = pd.read_csv('Loan 2.csv')

# %%
print(loan_1.info())
loan_1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  20000 non-null  object
#  1   Name                         20000 non-null  object
#  2   Gender                       19969 non-null  object
#  3   Age                          20000 non-null  int64
#  4   Income (USD)                 19250 non-null  float64
#  5   Income Stability             19187 non-null  object
#  6   Profession                   20000 non-null  object
#  7   Type of Employment           15311 non-null  object
#  8   Location                     20000 non-null  object
#  9   Loan Amount Request (USD)    20000 non-null  float64
#  10  Current Loan Expenses (USD)  19917 non-null  float64
#  11  Expense Type 1               20000 non-null  object
#  12  Expense Type 2               20000 non-null  object
# ...

# %%
print(loan_2.info())
loan_2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %%
loan_1.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           31
# Age                               0
# Income (USD)                    750
# Income Stability                813
# Profession                        0
# Type of Employment             4689
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)      83
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     1142
# Credit Score                    743
# No. of Defaults                   0
# Has Active Credit Card         1076
# Property ID                       0
# Property Age                    892
# Property Type                     0
# Property Location               160
# Co-Applicant                      0
# Property Price                    0
# dtype: int64

# %%
loan_2.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
loans = pd.concat([loan_1, loan_2], ignore_index=True)

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  50000 non-null  object
#  1   Name                         50000 non-null  object
#  2   Gender                       49916 non-null  object
#  3   Age                          50000 non-null  int64
#  4   Income (USD)                 44674 non-null  float64
#  5   Income Stability             47504 non-null  object
#  6   Profession                   50000 non-null  object
#  7   Type of Employment           38041 non-null  object
#  8   Location                     50000 non-null  object
#  9   Loan Amount Request (USD)    50000 non-null  float64
#  10  Current Loan Expenses (USD)  49745 non-null  float64
#  11  Expense Type 1               50000 non-null  object
#  12  Expense Type 2               50000 non-null  object
# ...

# %%
loans.isnull().sum()
# Out:
# Customer ID                        0
# Name                               0
# Gender                            84
# Age                                0
# Income (USD)                    5326
# Income Stability                2496
# Profession                         0
# Type of Employment             11959
# Location                           0
# Loan Amount Request (USD)          0
# Current Loan Expenses (USD)      255
# Expense Type 1                     0
# Expense Type 2                     0
# Dependents                      3635
# Credit Score                    2446
# No. of Defaults                    0
# Has Active Credit Card          2642
# Property ID                        0
# Property Age                    5742
# Property Type                      0
# Property Location                516
# Co-Applicant                       0
# Property Price                     0
# Loan Sanction Amount (USD)     20340
# dtype: int64

# %%
import pandas as pd



# Identify non-numeric values in 'Co-Applicant'
non_numeric_co_applicant = loans[~loans['Co-Applicant'].apply(lambda x: str(x).isdigit())]
print("Non-numeric values in 'Co-Applicant':")
print(non_numeric_co_applicant)

# Replace non-numeric values with NaN and then fill or remove them
loans['Co-Applicant'] = pd.to_numeric(loans['Co-Applicant'], errors='coerce')
loans['Co-Applicant'] = loans['Co-Applicant'].fillna(0).astype('int64')  # Assuming '0' for missing values

# Identify non-numeric values in 'Property Price'
non_numeric_property_price = loans[~loans['Property Price'].apply(lambda x: str(x).replace('.', '', 1).isdigit())]
print("Non-numeric values in 'Property Price':")
print(non_numeric_property_price)

# Replace non-numeric values with NaN and then fill or remove them
loans['Property Price'] = pd.to_numeric(loans['Property Price'], errors='coerce')
loans['Property Price'] = loans['Property Price'].fillna(0.0).astype('float64')  # Assuming '0.0' for missing values

# Verify the changes
print("\nUpdated data types for Loan 1:")
print(loans.dtypes)
# Out:
# Non-numeric values in 'Co-Applicant':
#       Customer ID                 Name Gender  Age  Income (USD)  \
# 38        C-18750        Karri Zeitler      M   36       2563.65
# 304        C-5160     Clayton Priester      F   61       1976.26
# 318       C-18516      Annalisa Conard      M   55       4517.65
# 328        C-9943  Carolann Beauchesne      F   61       1387.70
# 338       C-19101       Merideth Volpe      F   60           NaN
# ...           ...                  ...    ...  ...           ...
# 49312     C-19945  Danica Andrzejewski      F   20       4489.91
# 49531     C-14313       Nannie Augusta      M   61       3705.62
# 49611     C-13954          Nikki Resto      F   41       4130.76
# 49821     C-25387        Lizette Pfarr      F   61       3509.29
# 49965      C-3606       Haley Densmore      M   31       2503.23
#
#       Income Stability            Profession     Type of Employment  \
# 38                 Low  Commercial associate             Core staff
# ...

# %%
loans.isnull().sum()
# Out:
# Customer ID                        0
# Name                               0
# Gender                            84
# Age                                0
# Income (USD)                    5326
# Income Stability                2496
# Profession                         0
# Type of Employment             11959
# Location                           0
# Loan Amount Request (USD)          0
# Current Loan Expenses (USD)      255
# Expense Type 1                     0
# Expense Type 2                     0
# Dependents                      3635
# Credit Score                    2446
# No. of Defaults                    0
# Has Active Credit Card          2642
# Property ID                        0
# Property Age                    5742
# Property Type                      0
# Property Location                516
# Co-Applicant                       0
# Property Price                     0
# Loan Sanction Amount (USD)     20340
# dtype: int64

# %%
duplicates = loans[loans.duplicated(subset=['Customer ID'], keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Customer ID, Name, Gender, Age, Income (USD), Income Stability, Profession, Type of Employment, Location, Loan Amount Request (USD), Current Loan Expenses (USD), Expense Type 1, Expense Type 2, Dependents, Credit Score, No. of Defaults, Has Active Credit Card, Property ID, Property Age, Property Type, Property Location, Co-Applicant, Property Price, Loan Sanction Amount (USD)]
# Index: []
#
# [0 rows x 24 columns]

# %%
import numpy as np
conditions=[
    (loans['Income Stability'].notnull()),
    (loans['Income Stability'].isnull())&(loans['Profession']=='Commercial associate'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Working'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Pensioner'),#High
    (loans['Income Stability'].isnull())&(loans['Profession']=='State servant'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Unemployed'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Maternity leave'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Student'),#Low
    (loans['Income Stability'].isnull())&(loans['Profession']=='Businessman')#Low    
]

values=[
    loans['Income Stability'],
    'Low',
    'Low',
    'High',
    'Low',
    'Low',
    'Low',
    'Low',
    'High'
]
loans['Income Stability'] = np.select(conditions, values, default='Unknown')
loans['Income Stability'].isnull().sum()
# Out:
# 0

# %%
loans['Gender'].fillna(loans['Gender'].mode()[0], inplace=True)
loans['Gender'].isnull().sum()
# Out:
# 0

# %%
loans['Has Active Credit Card'].fillna(loans['Has Active Credit Card'].mode()[0], inplace=True)
loans['Has Active Credit Card'].isnull().sum()
# Out:
# 0

# %%
loans['Property Location'].fillna(loans['Property Location'].mode()[0], inplace=True)
loans['Property Location'].isnull().sum()
# Out:
# 0

# %%
loans.isnull().sum()
# Out:
# Customer ID                        0
# Name                               0
# Gender                             0
# Age                                0
# Income (USD)                    5326
# Income Stability                   0
# Profession                         0
# Type of Employment             11959
# Location                           0
# Loan Amount Request (USD)          0
# Current Loan Expenses (USD)      255
# Expense Type 1                     0
# Expense Type 2                     0
# Dependents                      3635
# Credit Score                    2446
# No. of Defaults                    0
# Has Active Credit Card             0
# Property ID                        0
# Property Age                    5742
# Property Type                      0
# Property Location                  0
# Co-Applicant                       0
# Property Price                     0
# Loan Sanction Amount (USD)     20340
# dtype: int64

# %%
# Fill missing values in 'Current Loan Expenses (USD)' with the mean
mean_value = loans['Current Loan Expenses (USD)'].mean()
loans['Current Loan Expenses (USD)'].fillna(mean_value, inplace=True)
loans['Current Loan Expenses (USD)'].isnull().sum()
# Out:
# 0

# %%
loans['Type of Employment'].fillna(loans['Type of Employment'].mode()[0], inplace=True)
loans['Type of Employment'].isnull().sum()
# Out:
# 0

# %%
# Fill missing values in 'Current Loan Expenses (USD)' with the mean
median_value = loans['Dependents'].median()
loans['Dependents'].fillna(median_value, inplace=True)
loans['Dependents'].isnull().sum()
# Out:
# 0

# %%
loans.isnull().sum()
# Out:
# Customer ID                        0
# Name                               0
# Gender                             0
# Age                                0
# Income (USD)                    5326
# Income Stability                   0
# Profession                         0
# Type of Employment                 0
# Location                           0
# Loan Amount Request (USD)          0
# Current Loan Expenses (USD)        0
# Expense Type 1                     0
# Expense Type 2                     0
# Dependents                         0
# Credit Score                    2446
# No. of Defaults                    0
# Has Active Credit Card             0
# Property ID                        0
# Property Age                    5742
# Property Type                      0
# Property Location                  0
# Co-Applicant                       0
# Property Price                     0
# Loan Sanction Amount (USD)     20340
# dtype: int64

# %%
# Assuming df is your loan dataset loaded properly
import matplotlib.pyplot as plt
# Select columns for KNN imputation
columns_for_knn = ['Income (USD)', 'Credit Score', 'Property Age','Loan Sanction Amount (USD)']

# Visualize histograms before imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(loans[col].dropna(), bins=30, color='blue', edgecolor='black')
    plt.title(f'Histogram of {col} - Before Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.impute import KNNImputer

# Perform KNN imputation
imputer = KNNImputer(n_neighbors=3)
loans_knn_imputed = pd.DataFrame(imputer.fit_transform(loans[columns_for_knn]), columns=columns_for_knn)

# Visualize histograms after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(loans_knn_imputed[col], bins=30, color='green', edgecolor='black')
    plt.title(f'Histogram of {col} - After KNN Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()
