# %%
import pandas as pd

loan_2 = pd.read_csv('Loan 2.csv')

# %%
loan_2.info()
loan_2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %%
loan_2.isnull()
# Out:
#        Customer ID   Name  Gender    Age  Income (USD)  Income Stability  \
# 0            False  False   False  False         False             False
# 1            False  False   False  False         False             False
# 2            False  False   False  False         False             False
# 3            False  False   False  False          True             False
# 4            False  False   False  False         False             False
# ...            ...    ...     ...    ...           ...               ...
# 29995        False  False   False  False         False             False
# 29996        False  False   False  False         False             False
# 29997        False  False   False  False          True             False
# 29998        False  False   False  False         False             False
# 29999        False  False   False  False         False             False
#
#        Profession  Type of Employment  Location  Loan Amount Request (USD)  \
# ...

# %%
loan_2.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                   4576
# Income Stability                  0
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
duplicates = loan_2[loan_2.duplicated(subset=['Customer ID'], keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Customer ID, Name, Gender, Age, Income (USD), Income Stability, Profession, Type of Employment, Location, Loan Amount Request (USD), Current Loan Expenses (USD), Expense Type 1, Expense Type 2, Dependents, Credit Score, No. of Defaults, Has Active Credit Card, Property ID, Property Age, Property Type, Property Location, Co-Applicant, Property Price, Loan Sanction Amount (USD)]
# Index: []
#
# [0 rows x 24 columns]

# %%
loan_2['Gender'].fillna(loan_2['Gender'].mode()[0], inplace=True)
loan_2['Gender'].isnull().sum()
# Out:
# 0

# %%
import numpy as np
conditions=[
    (loan_2['Income Stability'].notnull()),
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Commercial associate'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Working'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Pensioner'),#High
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='State servant'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Unemployed'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Maternity leave'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Student'),#Low
    (loan_2['Income Stability'].isnull())&(loan_2['Profession']=='Businessman')#Low    
]

values=[
    loan_2['Income Stability'],
    'Low',
    'Low',
    'High',
    'Low',
    'Low',
    'Low',
    'Low',
    'High'
]
loan_2['Income Stability'] = np.select(conditions, values, default='Unknown')
loan_2['Income Stability'].isnull().sum()
# Out:
# 0

# %%
loan_2['Type of Employment'].mode()
# Out:
# 0    Laborers
# Name: Type of Employment, dtype: object

# %%
loan_2['Profession'].unique()
# Out:
# array(['Working', 'Pensioner', 'State servant', 'Commercial associate',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype=object)

# %%
loan_2['Type of Employment'].unique()
# Out:
# array(['Sales staff', nan, 'High skill tech staff', 'Secretaries',
#        'Laborers', 'Managers', 'Cooking staff', 'Core staff', 'Drivers',
#        'Realty agents', 'Security staff', 'Accountants',
#        'Private service staff', 'Waiters/barmen staff', 'Medicine staff',
#        'Cleaning staff', 'Low-skill Laborers', 'HR staff', 'IT staff'],
#       dtype=object)

# %%
type_of_employment_conditions = [
    (loan_2['Type of Employment'].notnull()),
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Commercial associate'),  # Sales staff
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Working'),               # Loborers
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Pensioner'),             # Retired
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'State servant'),         # Core staff
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Unemployed'),            # Unemployed
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Maternity leave'),       # cleaning staff
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Student'),               # Student
    (loan_2['Type of Employment'].isnull()) & (loan_2['Profession'] == 'Businessman')            # HR staff
]

type_of_employment_values = [
    loan_2['Type of Employment'],
    
    'Sales staff',
    'Laborers',
    'Retired',
    'Core staff',
    'Managers',
    'Retired',
    'High skill tech staff',
    'Drivers'
    
]

loan_2['Type of Employment'] = np.select(type_of_employment_conditions, type_of_employment_values, default='Unknown')
print("Null values in 'Type of Employment':", loan_2['Type of Employment'].isnull().sum())
# Out:
# Null values in 'Type of Employment': 0

# %%
loan_2['Type of Employment'].value_counts()
# Out:
# Laborers                 5578
# Sales staff              3736
# Core staff               3230
# Managers                 2495
# Drivers                  1606
# Accountants              1379
# High skill tech staff    1307
# Medicine staff            864
# Security staff            579
# Cooking staff             566
# Private service staff     342
# Cleaning staff            341
# Low-skill Laborers        162
# Secretaries               161
# Waiters/barmen staff      149
# Realty agents              86
# IT staff                   77
# HR staff                   72
# Name: Type of Employment, dtype: int64

# %%
loan_2['Profession'].value_counts()
# Out:
# Working                 16926
# Commercial associate     7962
# Pensioner                2740
# State servant            2366
# Unemployed                  2
# Businessman                 2
# Student                     1
# Maternity leave             1
# Name: Profession, dtype: int64

# %%
loan_2['Type of Employment'].mode()
# Out:
# 0    Laborers
# Name: Type of Employment, dtype: object

# %%
loan_2.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                   4576
# Income Stability                  0
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
loan_2['Has Active Credit Card'].unique()
# Out:
# array([nan, 'Unpossessed', 'Active', 'Inactive'], dtype=object)

# %%
loan_2['Has Active Credit Card'].fillna(loan_2['Has Active Credit Card'].mode()[0], inplace=True)
loan_2['Has Active Credit Card'].isnull().sum()
# Out:
# 0

# %%
loan_2['Property Location'].fillna(loan_2['Property Location'].mode()[0], inplace=True)
loan_2['Property Location'].isnull().sum()
# Out:
# 0

# %%
loan_2['Current Loan Expenses (USD)'].mean()
# Out:
# 400.9368764248358

# %%
median_expenses=loan_2['Current Loan Expenses (USD)'].median()
print(median_expenses)
# Out:
# 375.205

# %%
import matplotlib.pyplot as plt
# Plot histogram of 'Current Loan Expenses (USD)'
plt.figure(figsize=(10, 6))
plt.hist(loan_2['Current Loan Expenses (USD)'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Current Loan Expenses (USD)')
plt.xlabel('Current Loan Expenses (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
loan_2['Current Loan Expenses (USD)'].fillna(median_expenses, inplace=True)
loan_2['Current Loan Expenses (USD)'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
# Plot histogram of 'Dependents'
plt.figure(figsize=(10, 6))
plt.hist(loan_2['Dependents'].dropna(), bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Dependents')
plt.xlabel('Dependents')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Calculate mean and median
mean_expenses = loan_2['Dependents'].mean()
median_expenses = loan_2['Dependents'].median()
print(mean_expenses)
print(median_expenses)
# Out:
# 2.2530265023448575
# 2.0

# %%
loan_2['Dependents'].fillna(median_expenses, inplace=True)
loan_2['Dependents'].isnull().sum()
# Out:
# 0

# %%
loan_2.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                   4576
# Income Stability                  0
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)       0
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card            0
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location                 0
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# Select columns for KNN imputation
columns_for_knn = ['Income (USD)', 'Credit Score', 'Property Age', 'Loan Sanction Amount (USD)']


# Check for missing values before imputation
print("Missing values before imputation:")
print(loan_2[columns_for_knn].isnull().sum())
# Out:
# Missing values before imputation:
# Income (USD)                  4576
# Credit Score                  1703
# Property Age                  4850
# Loan Sanction Amount (USD)     340
# dtype: int64

# %%
# Perform KNN imputation
imputer = KNNImputer(n_neighbors=5)
loan_2_knn_imputed = pd.DataFrame(imputer.fit_transform(loan_2[columns_for_knn]), columns=columns_for_knn)

# Assign imputed values back to the original dataframe
loan_2[columns_for_knn] = loan_2_knn_imputed[columns_for_knn]

# Check for missing values after imputation
print("\nMissing values after imputation:")
print(loan_2[columns_for_knn].isnull().sum())
# Out:
# Missing values after imputation:
# Income (USD)                  0
# Credit Score                  0
# Property Age                  0
# Loan Sanction Amount (USD)    0
# dtype: int64

# %%
# Calculate and display mean and median before and after imputation
print("\nBefore and After Imputation:")
for col in columns_for_knn:
    mean_before = loan_2[col].mean()
    median_before = loan_2[col].median()
    mean_after = loan_2_knn_imputed[col].mean()
    median_after = loan_2_knn_imputed[col].median()
    print(f"{col}: Mean before = {mean_before}, Median before = {median_before}")
    print(f"{col}: Mean after = {mean_after}, Median after = {median_after}")
# Out:
# Before and After Imputation:
# Income (USD): Mean before = 2637.024194511328, Median before = 2260.54
# Income (USD): Mean after = 2637.024194511328, Median after = 2260.54
# Credit Score: Mean before = 739.5584101016362, Median before = 740.11
# Credit Score: Mean after = 739.5584101016362, Median after = 740.11
# Property Age: Mean before = 2640.71495911727, Median before = 2270.35
# Property Age: Mean after = 2640.71495911727, Median after = 2270.35
# Loan Sanction Amount (USD): Mean before = 47726.501414322236, Median before = 35663.035
# Loan Sanction Amount (USD): Mean after = 47726.501414322236, Median after = 35663.035

# %%
# Visualize histograms before and after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(2, 2, i)
    plt.hist(loan_2[col].dropna(), bins=30, color='red', edgecolor='black', alpha=0.7, label='Before Imputation')
    plt.hist(loan_2_knn_imputed[col], bins=30, color='green', edgecolor='black', alpha=0.7, label='After Imputation')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Check for any remaining missing values in the entire dataframe
print("\nRemaining missing values in the entire dataframe after imputation:")
print(loan_2.isnull().sum())
# Out:
# Remaining missing values in the entire dataframe after imputation:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %%
sns.boxplot(loan_2['Income (USD)'])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# List of specific columns to check for outliers
specific_columns = [ 'Loan Amount Request (USD)', 'Credit Score', 'Property Price', 'Loan Sanction Amount (USD)']

# Create boxplots for each specified column
plt.figure(figsize=(18, 12))
for i, col in enumerate(specific_columns, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=loan_2[col])
    plt.title(f'Boxplot of {col}')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Create scatter plots for each specified column
plt.figure(figsize=(18, 12))
for i, col in enumerate(specific_columns, 1):
    plt.subplot(3, 2, i)
    plt.scatter(loan_2.index, loan_2[col])
    plt.title(f'Scatter Plot of {col}')
    plt.xlabel('Index')
    plt.ylabel(col)
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Function to handle outliers step by step
def handle_outliers(df, column):
    # Step 1: Arrange the data in increasing order
    sorted_data = df[column].sort_values().reset_index(drop=True)
    
    # Step 2: Calculate first (Q1) and third quartile (Q3)
    Q1 = sorted_data.quantile(0.25)
    Q3 = sorted_data.quantile(0.75)
    
    # Step 3: Find interquartile range (IQR)
    IQR = Q3 - Q1
    
    # Step 4: Find lower bound Q1 - 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR
    
    # Step 5: Find upper bound Q3 + 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Print the calculated values
    print(f'Column: {column}')
    print(f'Q1: {Q1}')
    print(f'Q3: {Q3}')
    print(f'IQR: {IQR}')
    print(f'Lower Bound: {lower_bound}')
    print(f'Upper Bound: {upper_bound}')
    
    # Handle outliers by capping
    df[column] = df[column].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# Handle outliers for each specified column
for col in specific_columns:
    handle_outliers(loan_2, col)

# Check the results
print("\nAfter handling outliers:")
print(loan_2[specific_columns].describe())
# Out:
# Column: Loan Amount Request (USD)
# Q1: 41177.755000000005
# Q3: 119964.605
# IQR: 78786.84999999999
# Lower Bound: -77002.51999999999
# Upper Bound: 238144.88
# Column: Credit Score
# Q1: 683.44
# Q3: 796.0025
# IQR: 112.5625
# Lower Bound: 514.59625
# Upper Bound: 964.84625
# Column: Property Price
# Q1: 60572.16
# Q3: 178880.72
# IQR: 118308.56
# Lower Bound: -116890.68
# Upper Bound: 356343.56
# Column: Loan Sanction Amount (USD)
# Q1: 0.0
# Q3: 74183.54000000001
# IQR: 74183.54000000001
# Lower Bound: -111275.31000000001
# Upper Bound: 185458.85000000003
#
# After handling outliers:
#        Loan Amount Request (USD)  Credit Score  Property Price  \
# count               30000.000000  30000.000000    30000.000000
# mean                87817.437653    739.558410   129661.354193
# std                 56222.583017     71.036628    86506.620071
# min                  6048.240000    580.000000     -999.000000
# 25%                 41177.755000    683.440000    60572.160000
# ...

# %%
# List of specific columns to check for outliers
specific_columns = [ 'Loan Amount Request (USD)', 'Credit Score', 'Property Price', 'Loan Sanction Amount (USD)']

# Create boxplots for each specified column
plt.figure(figsize=(18, 12))
for i, col in enumerate(specific_columns, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=loan_2[col])
    plt.title(f'Boxplot of {col}')
    plt.grid(True)

plt.tight_layout()
plt.show()
